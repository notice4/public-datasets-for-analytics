# %% [markdown]
# # API to DataFrame

# %%
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import pandas as pd

API_KEY = "6f835595c73525852b7bb3cc2e6c5a5d"

session = requests.Session()
session.headers.update({
    "User-Agent": "Mozilla/5.0",
    "Connection": "close",  })

# Retry on network-level errors
retries = Retry(total=5, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504])
session.mount("https://", HTTPAdapter(max_retries=retries))

# %%
final = pd.DataFrame()

# for j in range(1, 501):
#     url = "https://api.themoviedb.org/3/movie/popular"
#     params = {"api_key": API_KEY, "language": "en-US", "page": j}

#     try:
#         response = session.get(url, params=params, timeout=10)
#         response.raise_for_status()
#         data = response.json()
#     except Exception as e:
#         print(f"Error on page {j}: {e}")
#         continue

#     df = pd.DataFrame([{
#         "title": i["title"],
#         "release_date": i["release_date"],
#         "original_language": i["original_language"],
#         "popularity": i["popularity"],
#         "vote_count": i["vote_count"],
#         "vote_average": i["vote_average"],
#         "overview": i["overview"]
#     } for i in data["results"]])

#     final = pd.concat([final, df], ignore_index=True)

# %%
rq.get('https://api.themoviedb.org/3/movie/popular?api_key=6f835595c73525852b7bb3cc2e6c5a5d&language=en-US&page=1').json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/7QirCB1o80NEFpQGlQRZerZbQEp.jpg',
#    'genre_ids': [10749, 18],
#    'id': 1156594,
#    'original_language': 'es',
#    'original_title': 'Culpa nuestra',
#    'overview': "Jenna and Lion's wedding brings about the long-awaited reunion between Noah and Nick after their breakup. Nick's inability to forgive Noah stands as an insurmountable barrier. He, heir to his grandfather's businesses, and she, starting her professional life, resist fueling a flame that's still alive. But now that their paths have crossed again, will love be stronger than resentment?",
#    'popularity': 1096.6654,
#    'poster_path': '/yzqHt4m1SeY9FbPrfZ0C2Hi9x1s.jpg',
#    'release_date': '2025-10-15',
#    'title': 'Our Fault',
#    'video': False,
#    'vote_average': 7.869,
#    'vote_count': 302},
#   {'adult': False,
#    'backdrop_path': '/2yo2k8CmgZxfBQYAZ8TnHIYzEme.jpg',
#    'genre_ids': [28, 80, 53],
#    'id': 1072699,
# ...

# %%
final.to_csv("2025 popular Movies list.csv")
